# %%
import json
import os
import numpy as np
import pandas as pd
import torch

import pandas as pd
from sklearn.model_selection import train_test_split
from itertools import product
import time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import silhouette_score, roc_auc_score, balanced_accuracy_score, f1_score, accuracy_score, recall_score, precision_score
from sklearn.model_selection import train_test_split

from IPython.display import clear_output


def generate_param_configurations(configurations):
    keys, values_list = zip(*configurations.items())
    param_combinations = list(product(*values_list))

    result_configurations = []
    for combination in param_combinations:
        config_dict = dict(zip(keys, combination))
        result_configurations.append(config_dict)

    return result_configurations

# %%
import cv2
import sys
import argparse
import numpy as np
import torch
import torch.nn.functional as F
import os
import json

from src.utils import create_cfg, get_catalogs, register_dataset, extract_features
from src.arguments import get_parser
from src.dataloader import get_dataloader

from detectron2.engine import DefaultPredictor
from detectron2.modeling import build_model
from detectron2.structures.boxes import Boxes

# %%
##we change the dataset reference folder

parser = get_parser()

parser.add_argument("--model", type=str, required=True)
parser.add_argument("--output", type=str, required=True)


args = parser.parse_args(args=['--dataset-folder', './oral_datas/data/', 
                               '--model', './models/model.pth',
                               '--output', './assets/oral2_feats'])

# %%
args.data_augmentation = "none"
args.sampler = "TrainingSampler"

register_dataset(args)
cfg = create_cfg(args)

# %%
cfg.MODEL.WEIGHTS = args.model
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.MODEL.DEVICE='cpu'

predictor = DefaultPredictor(cfg)
model = predictor.model
# Out:
# The checkpoint state_dict contains keys that are not used by the model:
#   pixel_mean
#   pixel_std

# %%
def get_mapper(args, which):
    def train_mapper(dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict["file_name"], format="BGR")
        
        if args.data_augmentation == "full":
            image, transforms = T.apply_transform_gens([
                T.RandomFlip(),
                T.RandomBrightness(1-args.random_brightness, 1+args.random_brightness),
                T.RandomContrast(1-args.random_contrast, 1+args.random_contrast),
                T.RandomCrop("relative_range", [args.random_crop, 1]),
                T.Resize((800, 800)),
            ], image)
        elif args.data_augmentation == "crop-flip":
            image, transforms = T.apply_transform_gens([
                T.RandomFlip(),
                T.RandomCrop("relative_range", [args.random_crop, 1]),
                T.Resize((800, 800)),
            ], image)
        elif args.data_augmentation == "none":
            image, transforms = T.apply_transform_gens([
                T.Resize((800, 800)),
            ], image)
        else:
            raise Exception("Unknown data augmentation: %s " % args.data_augmentation)

        dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

        annos = [
            utils.transform_instance_annotations(obj, transforms, image.shape[:2])
            for obj in dataset_dict.pop("annotations")
            if obj.get("iscrowd", 0) == 0
        ]
        instances = utils.annotations_to_instances(annos, image.shape[:2])
        dataset_dict["instances"] = utils.filter_empty_instances(instances)

        return dataset_dict

    def coco_eval_mapper(dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict["file_name"], format="BGR")

        image, transforms = T.apply_transform_gens([
            T.Resize((800, 800)),
        ], image)

        dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

        annos = [
            utils.transform_instance_annotations(obj, transforms, image.shape[:2])
            for obj in dataset_dict.pop("annotations")
            if obj.get("iscrowd", 0) == 0
        ]
        instances = utils.annotations_to_instances(annos, image.shape[:2])
        dataset_dict["instances"] = utils.filter_empty_instances(instances)

        return dataset_dict
    

    def test_mapper(dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict["file_name"], format="BGR")
        
        image, transforms = T.apply_transform_gens([
            T.Resize((800, 800)),
        ], image)

        dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

        annos = [
            utils.transform_instance_annotations(obj, transforms, image.shape[:2])
            for obj in dataset_dict.pop("annotations")
            if obj.get("iscrowd", 0) == 0
        ]
        instances = utils.annotations_to_instances(annos, image.shape[:2])
        dataset_dict["instances"] = utils.filter_empty_instances(instances)

        return dataset_dict

    if which == "train":
        return train_mapper
    elif which == "test":
        return test_mapper
    elif which == 'val':
        return test_mapper
    elif which == "coco-eval":
        return coco_eval_mapper
    else:
        raise Exception("%s one of train/test/coco-eval" % (which, ))

# %%
cfg.DATASETS
# Out:
# CfgNode({'TRAIN': ('train_dataset',), 'PROPOSAL_FILES_TRAIN': (), 'PRECOMPUTED_PROPOSAL_TOPK_TRAIN': 2000, 'TEST': ('test_dataset',), 'PROPOSAL_FILES_TEST': (), 'PRECOMPUTED_PROPOSAL_TOPK_TEST': 1000})

# %%
import torch
import copy

from detectron2.data.build import get_detection_dataset_dicts, build_batch_data_loader, build_detection_test_loader
from detectron2.data.common import DatasetFromList, MapDataset
from detectron2.data import transforms as T
from detectron2.data import detection_utils as utils
from detectron2.data import DatasetMapper
from detectron2.data.samplers import TrainingSampler
from detectron2.data.samplers import RepeatFactorTrainingSampler

# %%
def build_detection_loader(cfg, mapper, which, args):
    assert which in ["train", "coco-eval", "test", "val"]
    
    dataset_dicts = get_detection_dataset_dicts(
        cfg.DATASETS.TRAIN if which == "train" else cfg.DATASETS.TEST,
        filter_empty=cfg.DATALOADER.FILTER_EMPTY_ANNOTATIONS,
        min_keypoints=cfg.MODEL.ROI_KEYPOINT_HEAD.MIN_KEYPOINTS_PER_IMAGE
        if cfg.MODEL.KEYPOINT_ON
        else 0,
        proposal_files=None,
    )

    dataset = DatasetFromList(dataset_dicts, copy=False)
    #Compute weights before appling data augmentation
    if args.sampler == "TrainingSampler":
        print("[SAMPLER] Selected TrainingSampler")
        dataset = MapDataset(dataset, mapper)
        sampler = TrainingSampler(len(dataset))
    elif args.sampler == "RepeatFactorTrainingSampler":
        print("[SAMPLER] Selected RepeatFactorTrainingSampler")
        repeat_factors = RepeatFactorTrainingSampler.repeat_factors_from_category_frequency(dataset_dicts, args.repeat_factor_th)
        sampler = RepeatFactorTrainingSampler(repeat_factors)
        dataset = MapDataset(dataset, mapper)
    else:
        raise Exception("Unknown Sampler %s" % args.sampler)

    return build_batch_data_loader(
        dataset,
        sampler,
        cfg.SOLVER.IMS_PER_BATCH,
        aspect_ratio_grouping=cfg.DATALOADER.ASPECT_RATIO_GROUPING,
        num_workers=cfg.DATALOADER.NUM_WORKERS,
    )

# %%
mapper = get_mapper(args, 'test')

# %%
(build_detection_loader(cfg, mapper, 'test', args))
# Out:
# [SAMPLER] Selected TrainingSampler

# %%
def extract_dataset(dataset_name, dataset_file, database):
    dataset_size = len(json.load(open(dataset_file))["images"])
    data_loader = get_dataloader(cfg, args, dataset_name)
    extracted = 0
    for batch in data_loader:
        for elem in batch:
            file_name = elem["file_name"].split("/")[-1]
            if file_name not in database:
                database[file_name] = list()
                features = extract_features(model, elem["image"], elem["instances"].gt_boxes.to(model.device))
                for roi, features_vector, type in zip(elem["instances"].gt_boxes, features, elem["instances"].gt_classes):
                    database[file_name].append(dict(
                        roi=roi.tolist(),
                        features=features_vector.tolist(),
                        type=type.item()
                    ))
                extracted += 1
                print("Extracted: %s  progress: %.3f%%" % (elem["file_name"], 100*extracted/dataset_size))
            if extracted == dataset_size:
                return

# %%
train_database = dict()
test_database = dict()

# %%
for dataset_name, dataset_file, database in zip(["train", "test"], 
                                                ["./oral_datas/data/train.json", "./oral_datas/data/test.json"], #analogous for validation
                                                [train_database, test_database]):
    print("Extrating dataset: %s" % (dataset_name, ))
    extract_dataset(dataset_name, dataset_file, database)

clear_output()

# %%
json.dump(train_database, open(os.path.join('./oral_datas/data', "oral2_train_features.json"), "w"))
json.dump(test_database, open(os.path.join('./oral_datas/data', "oral2_test_features.json"), "w")) #analogous for validation

# %%
train_file = open('datasets/lesions/train.json')
train_data = json.load(train_file)
train_file.close()


test_file = open('datasets/lesions/test.json')
test_data = json.load(test_file)
test_file.close()

# %%
train_data
# Out:
# {'images': [{'id': 1732,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/8cc77a9f9081530e6d9b49ec472d934c.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '8cc77a9f9081530e6d9b49ec472d934c.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1651,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/d4777a6154b22adf50bcde578aa856e9.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'd4777a6154b22adf50bcde578aa856e9.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2406,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3343 (1).jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN3343 (1).jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2027,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 213.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 213.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1845,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3981.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN3981.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1606,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/fe3d36915efad70bd9fd3b84c696c734.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'fe3d36915efad70bd9fd3b84c696c734.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1857,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_8691.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_8691.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1719,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/aecf83cc073e4e6f275f50d0fc3ab008.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'aecf83cc073e4e6f275f50d0fc3ab008.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1809,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3408.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'DSCN3408.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2051,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 096.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 096.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1844,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 004.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 004.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1906,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 020.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 020.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1935,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 0261.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 0261.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2393,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_7572.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_7572.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1733,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/96b8ac64f7d81ea675d5b93e2abe62f1.jpg',
#    'width': 2112,
#    'height': 2816,
#    'file_name': '96b8ac64f7d81ea675d5b93e2abe62f1.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2360,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2217.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2217.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2001,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_4257.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_4257.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1758,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/4333c08efe2e29b2af8c0d3de155b371.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '4333c08efe2e29b2af8c0d3de155b371.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1660,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/eccc7543f2fa526bced0663b4e53a94f.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'eccc7543f2fa526bced0663b4e53a94f.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2405,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9380 (1).JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_9380 (1).JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1590,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/a8e9686609015e13281a30245ce93306.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'a8e9686609015e13281a30245ce93306.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2061,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN8183.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8183.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2209,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/Immagine 213.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 213.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1753,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/32f5e4fbf3489ae23b1a761740ab57ae.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '32f5e4fbf3489ae23b1a761740ab57ae.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2026,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 139.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 139.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2327,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9221.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_9221.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2364,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9220.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_9220.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2324,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_7952.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_7952.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2050,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3733.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN3733.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2366,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1211.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_1211.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1594,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/c6a240e21455ccc3ff51fcc6cd74116a.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'c6a240e21455ccc3ff51fcc6cd74116a.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1905,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9380.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_9380.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2058,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN6823.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'DSCN6823.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1886,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN5363.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN5363.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1981,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN1787.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN1787.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2203,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/Immagine 0221.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 0221.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1903,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9556.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_9556.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2361,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_0657.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_0657.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2423,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_0478.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_0478.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1635,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/0d361ec0cfbd606a6b8adfa70245b307.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '0d361ec0cfbd606a6b8adfa70245b307.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1646,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/5d6bb5e1e332d5b8ed277c371ce82eca.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '5d6bb5e1e332d5b8ed277c371ce82eca.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1735,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/875337fdcdec1f6e09a006b56da67cac.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '875337fdcdec1f6e09a006b56da67cac.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1774,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/577d60d70a6613939f31eea890f28e03.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '577d60d70a6613939f31eea890f28e03.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1763,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/4a78ebbc501567ba687768f546a82622.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': '4a78ebbc501567ba687768f546a82622.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1916,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_3645.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_3645.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1970,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3734.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN3734.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1892,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN8810.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8810.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2200,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/Immagine 116.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 116.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1900,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2233.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2233.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1876,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_3118.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_3118.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1866,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Foto 13 nov. 081.jpg',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'Foto 13 nov. 081.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1661,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/d33060a1260da87fc9e3d49c9e7b80e3.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'd33060a1260da87fc9e3d49c9e7b80e3.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2056,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3188.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'DSCN3188.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1947,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN0698.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN0698.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1581,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/546c10c22c19b84be91b8f0211475c88.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '546c10c22c19b84be91b8f0211475c88.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2010,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_4458.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_4458.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1639,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/7471a9315da37b692b406aa7267c0be6.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '7471a9315da37b692b406aa7267c0be6.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2015,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 010.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 010.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2066,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN4676.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN4676.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2012,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3618.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'DSCN3618.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1689,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/21eee397bdf09518f1332c624d28458c.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '21eee397bdf09518f1332c624d28458c.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2069,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN1149.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN1149.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2412,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2975.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2975.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2007,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 0251.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 0251.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2188,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/DSC_8785.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_8785.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2355,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1480.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_1480.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1723,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/f7d5e8ca46839f3604ea27ac22c3cced.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'f7d5e8ca46839f3604ea27ac22c3cced.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2205,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/DSC_9556.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_9556.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2042,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_6063.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_6063.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2041,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN6522.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN6522.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2175,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN8419 (1).jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8419 (1).jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1986,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN8973.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8973.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1921,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN7050.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN7050.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2048,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 246.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 246.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1679,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/9af90f97dbf493dacb7bd83d66d420d1.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '9af90f97dbf493dacb7bd83d66d420d1.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1652,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/b6e49fa23eb3402da4d68a118393288f.jpg',
#    'width': 2112,
#    'height': 2816,
#    'file_name': 'b6e49fa23eb3402da4d68a118393288f.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2370,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1764.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_1764.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2163,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_0157.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_0157.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2099,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/ULCERA TRAUMATICA/DSC_4595.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_4595.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1860,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN0699.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN0699.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1971,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN1253.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN1253.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2032,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/14-05 019.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '14-05 019.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1770,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/61fe348c0e8590cf62b59a33e38deedd.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '61fe348c0e8590cf62b59a33e38deedd.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1992,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_3261.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_3261.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2325,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_7944.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_7944.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1818,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_3650.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_3650.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2140,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/28-05-2008 016.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '28-05-2008 016.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2187,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/Immagine 116.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 116.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2053,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 058.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 058.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2025,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN0485.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN0485.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2201,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/DSCN8419 .jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8419 .jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2172,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 116.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 116.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1724,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/c1244a8c14b8168f4a789ad34834b2ad.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'c1244a8c14b8168f4a789ad34834b2ad.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2373,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1500.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_1500.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2369,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_3231.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_3231.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1913,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3407.JPG',
#    'width': 2048,
#    'height': 1536,
#    'file_name': 'DSCN3407.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2367,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2262.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2262.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1855,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_8785.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_8785.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1914,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/5-4-13 022.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '5-4-13 022.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2341,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_7213.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_7213.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2018,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_4595.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_4595.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2208,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/DSC_4595.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_4595.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1884,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 005.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 005.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1706,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/88571744431c841066da263e1bd58e6d.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': '88571744431c841066da263e1bd58e6d.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2396,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_4715.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_4715.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2033,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_5283.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_5283.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1804,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 307.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 307.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2342,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_8965.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_8965.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1984,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2689.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2689.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1605,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/36701fd15d04c0f15bf31a70cd5d6c31.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '36701fd15d04c0f15bf31a70cd5d6c31.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1991,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 248.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 248.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1711,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/bec1caeb879973255e17f448e2e3fcb4.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'bec1caeb879973255e17f448e2e3fcb4.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2404,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_0157 (1).JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_0157 (1).JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1968,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_5282.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'DSC_5282.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1954,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_4358.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_4358.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2363,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_9025.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_9025.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2064,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN1099.JPG',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN1099.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2339,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_8539.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_8539.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2420,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_2535.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_2535.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2206,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/DSC_3645.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_3645.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2207,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Anchors/ULCERA TRAUMATICA/imm 041.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'imm 041.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1907,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN8419.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'DSCN8419.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2024,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/Immagine 009.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'Immagine 009.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1727,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/b53ca7b652c663cf51d4f12b5d857578.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': 'b53ca7b652c663cf51d4f12b5d857578.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1779,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/af6f0a3e0fd5804d4a99ff5621da4810.JPG',
#    'width': 3008,
#    'height': 2000,
#    'file_name': 'af6f0a3e0fd5804d4a99ff5621da4810.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2131,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/28-05-2008 017.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '28-05-2008 017.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2359,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1117.JPG',
#    'width': 4800,
#    'height': 3200,
#    'file_name': 'DSC_1117.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 2409,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSC_1978.JPG',
#    'width': 6000,
#    'height': 4000,
#    'file_name': 'DSC_1978.JPG',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1755,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/8ff6e083e5b2af7af66c2ed7c6108a19.jpg',
#    'width': 2816,
#    'height': 2112,
#    'file_name': '8ff6e083e5b2af7af66c2ed7c6108a19.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1675,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/4eb3e9176804c9994136732f4dc38a0f.jpg',
#    'width': 2112,
#    'height': 2816,
#    'file_name': '4eb3e9176804c9994136732f4dc38a0f.jpg',
#    'annotated': False,
#    'annotating': [],
#    'num_annotations': 0,
#    'metadata': {},
#    'deleted': False,
#    'milliseconds': 0,
#    'events': [],
#    'regenerate_thumbnail': False},
#   {'id': 1875,
#    'dataset_id': 2,
#    'category_ids': [],
#    'path': '/datasets/oral1/DSCN3513.JPG',
#    'width': 2816,
# ...
#      1106.6,
#      1245.8,
#      1306.4,
#      1162.6,
#      1566.2,
#      1052.7,
#      1606.1,
#      896.2,
#      1399.7]],
#    'area': 120221,
#    'bbox': [896.0, 1107.0, 350.0, 499.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#eb4fed',
#    'metadata': {}},
#   {'id': 1814,
#    'image_id': 1962,
#    'category_id': 2,
#    'segmentation': [[1136.9,
#      833.9,
#      1175.6,
#      774.6,
#      1175.6,
#      769.4,
#      1196.3,
#      707.4,
#      1206.6,
#      694.5,
#      1242.7,
#      689.3,
#      1526.8,
#      689.3,
#      1575.8,
#      699.7,
#      1591.3,
#      741.0,
#      1645.5,
#      854.6,
#      1645.5,
#      895.9,
#      1648.1,
#      895.9,
#      1666.2,
#      1058.6,
#      1676.5,
#      1058.6,
#      1676.5,
#      1071.5,
#      1686.9,
#      1118.0,
#      1686.9,
#      1138.6,
#      1689.4,
#      1164.4,
#      1689.4,
#      1272.9,
#      1694.6,
#      1371.0,
#      1686.9,
#      1376.2,
#      1684.3,
#      1381.3,
#      1679.1,
#      1386.5,
#      1593.9,
#      1422.7,
#      1588.7,
#      1422.7,
#      1462.2,
#      1458.8,
#      1459.6,
#      1461.4,
#      1317.6,
#      1500.1,
#      1266.0,
#      1430.4,
#      1266.0,
#      1293.5,
#      1211.8,
#      1221.3,
#      1242.7,
#      1079.2,
#      1232.4,
#      1006.9,
#      1162.7,
#      968.2,
#      1131.7,
#      826.2]],
#    'area': 341174,
#    'bbox': [1132.0, 689.0, 563.0, 811.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#6e61f2',
#    'metadata': {}},
#   {'id': 1567,
#    'image_id': 1670,
#    'category_id': 2,
#    'segmentation': [[1412.6,
#      1577.9,
#      1393.0,
#      1585.8,
#      1295.1,
#      1558.3,
#      1220.6,
#      1474.1,
#      1275.5,
#      1331.2,
#      1377.3,
#      1315.5,
#      1447.8,
#      1384.0,
#      1471.3,
#      1507.4,
#      1414.5,
#      1577.9]],
#    'area': 47637,
#    'bbox': [1221.0, 1316.0, 250.0, 270.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#2be8b0',
#    'metadata': {}},
#   {'id': 1568,
#    'image_id': 1670,
#    'category_id': 2,
#    'segmentation': [[1469.4,
#      910.1,
#      1393.0,
#      869.0,
#      1385.2,
#      861.1,
#      1357.7,
#      771.0,
#      1455.7,
#      696.6,
#      1549.7,
#      737.8,
#      1561.4,
#      829.8,
#      1471.3,
#      906.2,
#      1469.4,
#      906.2]],
#    'area': 28574,
#    'bbox': [1358.0, 697.0, 203.0, 213.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#28a289',
#    'metadata': {}},
#   {'id': 1569,
#    'image_id': 1670,
#    'category_id': 2,
#    'segmentation': [[194.4,
#      1632.8,
#      151.3,
#      1660.2,
#      145.4,
#      1660.2,
#      74.9,
#      1579.9,
#      76.9,
#      1577.9,
#      76.9,
#      1562.3,
#      67.1,
#      1480.0,
#      71.0,
#      1472.2,
#      167.0,
#      1436.9,
#      170.9,
#      1436.9,
#      237.5,
#      1521.1,
#      243.4,
#      1525.1,
#      198.3,
#      1628.8,
#      198.3,
#      1634.7]],
#    'area': 25716,
#    'bbox': [67.0, 1437.0, 176.0, 223.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#f3a270',
#    'metadata': {}},
#   {'id': 1570,
#    'image_id': 1670,
#    'category_id': 2,
#    'segmentation': [[519.5,
#      1384.0,
#      511.7,
#      1386.0,
#      431.4,
#      1366.4,
#      429.4,
#      1362.5,
#      425.5,
#      1362.5,
#      405.9,
#      1292.0,
#      400.0,
#      1286.1,
#      460.8,
#      1227.4,
#      550.8,
#      1274.4,
#      576.3,
#      1331.2,
#      519.5,
#      1382.1,
#      513.6,
#      1380.1]],
#    'area': 17822,
#    'bbox': [400.0, 1228.0, 176.0, 158.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#a4e231',
#    'metadata': {}},
#   {'id': 2137,
#    'image_id': 2144,
#    'category_id': 2,
#    'segmentation': [[1062.1,
#      932.6,
#      1000.4,
#      726.9,
#      1037.8,
#      637.2,
#      1237.9,
#      500.7,
#      1451.0,
#      525.0,
#      1595.0,
#      549.3,
#      1630.5,
#      811.1,
#      1456.6,
#      1106.5,
#      1254.7,
#      1110.2,
#      1062.1,
#      928.9]],
#    'area': 287919,
#    'bbox': [1001.0, 501.0, 630.0, 609.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#0bbfb1',
#    'metadata': {}},
#   {'id': 1636,
#    'image_id': 1595,
#    'category_id': 2,
#    'segmentation': [[2287.7,
#      1811.8,
#      2402.1,
#      1991.6,
#      2369.4,
#      2151.0,
#      2275.4,
#      2159.2,
#      2120.1,
#      2146.9,
#      2075.1,
#      2065.2,
#      2026.1,
#      1893.5,
#      2111.9,
#      1795.4,
#      2259.0,
#      1770.9,
#      2291.7,
#      1820.0]],
#    'area': 106882,
#    'bbox': [2026.0, 1771.0, 376.0, 388.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#50d9f3',
#    'metadata': {}},
#   {'id': 1973,
#    'image_id': 2276,
#    'category_id': 2,
#    'segmentation': [[1032.5,
#      1096.4,
#      1201.5,
#      938.6,
#      1351.7,
#      951.8,
#      1501.9,
#      1141.4,
#      1458.7,
#      1353.6,
#      1240.9,
#      1398.7,
#      1107.6,
#      1340.5,
#      1032.5,
#      1109.5]],
#    'area': 157106,
#    'bbox': [1033.0, 939.0, 469.0, 460.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#a363dd',
#    'metadata': {}},
#   {'id': 1649,
#    'image_id': 1694,
#    'category_id': 2,
#    'segmentation': [[1099.3,
#      1466.3,
#      1282.5,
#      1482.9,
#      1309.1,
#      1592.8,
#      1259.1,
#      1762.7,
#      1149.2,
#      1865.9,
#      1076.0,
#      1849.2,
#      986.1,
#      1682.7]],
#    'area': 88704,
#    'bbox': [986.0, 1466.0, 323.0, 400.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#55e7ad',
#    'metadata': {}},
#   {'id': 2116,
#    'image_id': 2388,
#    'category_id': 2,
#    'segmentation': [[3681.1,
#      1460.4,
#      3933.2,
#      2115.0,
#      3570.5,
#      2362.7,
#      3128.3,
#      2362.7,
#      2867.3,
#      1725.8,
#      3203.4,
#      1416.2,
#      3685.5,
#      1456.0]],
#    'area': 725883,
#    'bbox': [2868.0, 1416.0, 1065.0, 947.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#ad0cb3',
#    'metadata': {}},
#   {'id': 1881,
#    'image_id': 2168,
#    'category_id': 2,
#    'segmentation': [[775.9,
#      855.1,
#      838.0,
#      636.6,
#      905.9,
#      503.7,
#      1052.1,
#      480.1,
#      1205.6,
#      480.1,
#      1309.0,
#      642.5,
#      1342.9,
#      931.9,
#      1165.8,
#      1095.8,
#      1156.9,
#      1101.7,
#      880.8,
#      1079.6,
#      854.2,
#      1079.6,
#      774.5,
#      861.0]],
#    'area': 279948,
#    'bbox': [775.0, 480.0, 568.0, 622.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#57d941',
#    'metadata': {}},
#   {'id': 2153,
#    'image_id': 2286,
#    'category_id': 2,
#    'segmentation': [[711.3,
#      698.7,
#      788.8,
#      460.7,
#      949.2,
#      404.9,
#      1033.5,
#      419.9,
#      1304.1,
#      784.3,
#      1214.4,
#      1204.5,
#      892.1,
#      1239.8,
#      685.4,
#      1235.8,
#      673.2,
#      933.9,
#      711.3,
#      700.0]],
#    'area': 409052,
#    'bbox': [673.0, 405.0, 631.0, 835.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#da32e3',
#    'metadata': {}},
#   {'id': 1978,
#    'image_id': 2316,
#    'category_id': 2,
#    'segmentation': [[1665.2,
#      987.5,
#      1832.4,
#      747.1,
#      2115.9,
#      538.7,
#      2309.3,
#      613.8,
#      2373.1,
#      884.2,
#      2067.1,
#      1282.3,
#      1807.9,
#      1239.1,
#      1663.4,
#      987.5],
#     [856.0, 942.4, 858.2, 945.7, 856.0, 948.0],
#     [858.2,
#      945.7,
#      936.7,
#      863.5,
#      1180.8,
#      735.9,
#      1642.7,
#      741.5,
#      1625.8,
#      925.5,
#      1436.2,
#      1231.6,
#      1083.2,
#      1287.9]],
#    'area': 637962,
#    'bbox': [856.0, 539.0, 1517.0, 749.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#8cc32d',
#    'metadata': {}},
#   {'id': 1644,
#    'image_id': 1784,
#    'category_id': 2,
#    'segmentation': [[1054.9,
#      730.0,
#      930.6,
#      819.4,
#      762.8,
#      823.8,
#      680.0,
#      695.2,
#      743.2,
#      579.6,
#      869.6,
#      514.2,
#      987.3,
#      507.7,
#      1067.6,
#      579.3],
#     [1046.2,
#      749.7,
#      1209.6,
#      751.8,
#      1266.3,
#      819.4,
#      1203.1,
#      948.0,
#      1048.3,
#      1019.9,
#      926.3,
#      958.9,
#      932.8,
#      839.0,
#      1054.9,
#      738.8]],
#    'area': 158173,
#    'bbox': [680.0, 508.0, 586.0, 512.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#4ae2cd',
#    'metadata': {}},
#   {'id': 1815,
#    'image_id': 2075,
#    'category_id': 2,
#    'segmentation': [[1025.9,
#      1017.3,
#      1064.6,
#      890.7,
#      1064.6,
#      885.6,
#      1067.2,
#      885.6,
#      1173.0,
#      828.8,
#      1340.9,
#      831.4,
#      1526.8,
#      999.2,
#      1526.8,
#      1001.8,
#      1529.4,
#      1001.8,
#      1547.4,
#      1149.0,
#      1547.4,
#      1378.8,
#      1415.7,
#      1458.8,
#      1266.0,
#      1497.5,
#      1139.5,
#      1383.9,
#      1103.3,
#      1182.5,
#      1103.3,
#      1146.4,
#      1082.7,
#      1076.7,
#      1023.3,
#      1017.3]],
#    'area': 257762,
#    'bbox': [1024.0, 829.0, 523.0, 668.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#e42be4',
#    'metadata': {}},
#   {'id': 2063,
#    'image_id': 2198,
#    'category_id': 2,
#    'segmentation': [[1685.6,
#      593.5,
#      1908.8,
#      295.9,
#      2115.4,
#      304.2,
#      2231.1,
#      667.9,
#      2231.1,
#      1006.8,
#      1900.5,
#      1048.1,
#      1693.9,
#      973.7,
#      1677.3,
#      610.0]],
#    'area': 339157,
#    'bbox': [1677.0, 296.0, 554.0, 752.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#a0201d',
#    'metadata': {}},
#   {'id': 1980,
#    'image_id': 2297,
#    'category_id': 2,
#    'segmentation': [[1456.8,
#      1445.6,
#      1261.5,
#      1481.3,
#      1083.2,
#      1346.1,
#      1113.2,
#      1079.5,
#      1289.7,
#      675.8,
#      1764.8,
#      525.6,
#      1794.8,
#      936.8,
#      1458.7,
#      1447.5]],
#    'area': 442696,
#    'bbox': [1083.0, 526.0, 712.0, 955.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#fa9b0c',
#    'metadata': {}},
#   {'id': 1643,
#    'image_id': 1673,
#    'category_id': 2,
#    'segmentation': [[1328.1,
#      610.2,
#      1398.0,
#      730.1,
#      1353.1,
#      857.4,
#      1225.7,
#      884.9,
#      1148.2,
#      815.0,
#      1115.8,
#      695.1,
#      1165.7,
#      577.7,
#      1283.1,
#      572.7,
#      1333.1,
#      620.2]],
#    'area': 64087,
#    'bbox': [1116.0, 573.0, 282.0, 312.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#27ec1e',
#    'metadata': {}},
#   {'id': 2002,
#    'image_id': 2319,
#    'category_id': 2,
#    'segmentation': [[1752.7,
#      1316.6,
#      1796.9,
#      1180.0,
#      2032.3,
#      1287.2,
#      1998.6,
#      1480.6,
#      1887.2,
#      1482.7,
#      1773.7,
#      1432.2,
#      1750.6,
#      1318.7],
#     [1372.3, 1377.6, 1372.4, 1379.5, 1368.1, 1383.9],
#     [1372.4,
#      1379.5,
#      1380.7,
#      1371.3,
#      1538.3,
#      1404.9,
#      1498.4,
#      1552.1,
#      1382.8,
#      1495.3],
#     [1017.0, 1388.1, 1019.0, 1391.0, 1014.9, 1394.4],
#     [1019.0, 1391.0, 1124.2, 1304.0, 1193.6, 1396.5, 1080.1, 1482.7],
#     [890.9, 759.6, 1019.1, 763.8, 1065.4, 942.5, 918.3, 1016.1, 781.6, 839.5]],
#    'area': 142610,
#    'bbox': [782.0, 760.0, 1250.0, 792.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#e79f30',
#    'metadata': {}},
#   {'id': 1982,
#    'image_id': 2295,
#    'category_id': 2,
#    'segmentation': [[1145.1,
#      945.5,
#      1232.3,
#      693.6,
#      1503.6,
#      809.9,
#      1697.4,
#      1061.7,
#      1484.2,
#      1236.1,
#      1193.6,
#      1226.5,
#      1145.1,
#      955.2]],
#    'area': 198902,
#    'bbox': [1145.0, 694.0, 552.0, 542.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#e64af5',
#    'metadata': {}},
#   {'id': 2027,
#    'image_id': 2345,
#    'category_id': 2,
#    'segmentation': [[1890.5,
#      1336.5,
#      1896.4,
#      1202.6,
#      2271.9,
#      1214.3,
#      2490.2,
#      1243.4,
#      2499.0,
#      1441.3,
#      2452.4,
#      1697.5,
#      2263.2,
#      1697.5,
#      2004.1,
#      1589.8,
#      1887.6,
#      1339.4]],
#    'area': 245617,
#    'bbox': [1888.0, 1203.0, 611.0, 495.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#e4f423',
#    'metadata': {}},
#   {'id': 1627,
#    'image_id': 1596,
#    'category_id': 2,
#    'segmentation': [[980.9,
#      522.8,
#      1068.3,
#      467.8,
#      1175.7,
#      507.8,
#      1228.2,
#      630.2,
#      1178.2,
#      737.6,
#      1028.4,
#      745.0,
#      945.9,
#      617.7,
#      983.4,
#      522.8]],
#    'area': 55831,
#    'bbox': [946.0, 468.0, 282.0, 277.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#1a17bd',
#    'metadata': {}},
#   {'id': 2159,
#    'image_id': 2191,
#    'category_id': 2,
#    'segmentation': [[671.8,
#      799.3,
#      726.2,
#      757.1,
#      813.2,
#      717.7,
#      1162.7,
#      758.5,
#      1196.7,
#      890.4,
#      1024.0,
#      1105.2,
#      757.5,
#      1135.1,
#      697.7,
#      1064.4,
#      561.7,
#      891.7,
#      631.0,
#      905.3,
#      669.1,
#      803.4]],
#    'area': 180096,
#    'bbox': [562.0, 718.0, 635.0, 417.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#6eef7e',
#    'metadata': {}},
#   {'id': 2133,
#    'image_id': 1856,
#    'category_id': 2,
#    'segmentation': [[636.5,
#      486.5,
#      782.0,
#      462.1,
#      836.4,
#      558.6,
#      792.8,
#      701.4,
#      671.8,
#      708.2,
#      635.1,
#      485.2],
#     [1055.3,
#      524.6,
#      1048.5,
#      734.0,
#      937.0,
#      727.2,
#      875.8,
#      653.8,
#      851.3,
#      536.8,
#      869.0,
#      466.1,
#      971.0,
#      467.5,
#      1052.6,
#      524.6],
#     [841.8,
#      713.6,
#      960.1,
#      812.9,
#      919.3,
#      995.1,
#      794.2,
#      1031.8,
#      705.8,
#      921.7,
#      731.6,
#      763.9]],
#    'area': 137962,
#    'bbox': [635.0, 462.0, 420.0, 570.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#c2721f',
#    'metadata': {}},
#   {'id': 1621,
#    'image_id': 1681,
#    'category_id': 2,
#    'segmentation': [[1308.1,
#      879.9,
#      1540.4,
#      807.5,
#      1675.2,
#      815.0,
#      1780.1,
#      939.9,
#      1697.7,
#      1109.7,
#      1520.4,
#      1232.1,
#      1325.6,
#      1252.1,
#      1283.1,
#      1239.6,
#      1173.2,
#      1052.3,
#      1308.1,
#      874.9]],
#    'area': 185519,
#    'bbox': [1173.0, 808.0, 607.0, 444.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#a72d1c',
#    'metadata': {}},
#   {'id': 1618,
#    'image_id': 1769,
#    'category_id': 2,
#    'segmentation': [[676.2,
#      909.9,
#      943.4,
#      830.0,
#      1040.8,
#      802.5,
#      1143.3,
#      832.5,
#      1190.7,
#      912.4,
#      1288.1,
#      949.9,
#      1340.6,
#      1009.8,
#      1363.0,
#      1049.8,
#      1333.1,
#      1064.7,
#      1383.0,
#      1089.7,
#      1385.5,
#      1182.1,
#      1298.1,
#      1244.6,
#      1208.2,
#      1302.0,
#      1070.8,
#      1302.0,
#      938.4,
#      1287.0,
#      876.0,
#      1269.5,
#      738.6,
#      1197.1,
#      671.2,
#      1084.7,
#      608.8,
#      1027.3,
#      673.7,
#      914.9]],
#    'area': 270251,
#    'bbox': [609.0, 803.0, 777.0, 499.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#5a08fa',
#    'metadata': {}},
#   {'id': 1903,
#    'image_id': 2121,
#    'category_id': 2,
#    'segmentation': [[1472.0,
#      2405.8,
#      1451.4,
#      2282.5,
#      1636.3,
#      1940.1,
#      1951.4,
#      1899.0,
#      2321.2,
#      2022.3,
#      2458.2,
#      2501.7,
#      2245.9,
#      2953.7,
#      1752.8,
#      2981.1,
#      1519.9,
#      2782.5,
#      1485.7,
#      2433.2]],
#    'area': 853956,
#    'bbox': [1451.0, 1899.0, 1007.0, 1082.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#fa7e54',
#    'metadata': {}},
#   {'id': 2191,
#    'image_id': 2418,
#    'category_id': 2,
#    'segmentation': [[3172.6,
#      1503.8,
#      3539.4,
#      1811.2,
#      3496.2,
#      2145.6,
#      3178.0,
#      2490.8,
#      2768.1,
#      2258.9,
#      2455.2,
#      1881.3,
#      2617.0,
#      1433.7,
#      3172.6,
#      1514.6]],
#    'area': 749050,
#    'bbox': [2455.0, 1434.0, 1084.0, 1056.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#5eeafb',
#    'metadata': {}},
#   {'id': 1959,
#    'image_id': 2292,
#    'category_id': 2,
#    'segmentation': [[828.8, 1430.0, 823.5, 1436.4, 810.1, 1436.2],
#     [823.5,
#      1436.4,
#      1190.2,
#      1442.4,
#      1327.2,
#      1697.9,
#      1364.6,
#      2140.2,
#      1102.9,
#      2314.6,
#      866.2,
#      2345.7,
#      511.1,
#      2059.2,
#      542.3,
#      1778.8]],
#    'area': 589930,
#    'bbox': [511.0, 1430.0, 854.0, 916.0],
#    'iscrowd': False,
#    'isbbox': False,
#    'color': '#6af18f',
#    'metadata': {}}],
#  'categories': [{'id': 1,
#    'name': 'neoplastic',
#    'supercategory': '',
#    'color': '#fc0000',
#    'metadata': {},
#    'keypoint_colors': []},
#   {'id': 2,
#    'name': 'aphthous',
#    'supercategory': '',
#    'color': '#00fc00',
#    'metadata': {},
#    'keypoint_colors': []},
#   {'id': 3,
#    'name': 'traumatic',
#    'supercategory': '',
#    'color': '#fcfcfc',
#    'metadata': {},
#    'keypoint_colors': []}]}

# %%
len(train_data['annotations']) + len(test_data['annotations'])
# Out:
# 499

# %%
dataset = train_data
category_count = dict()
for annotation in dataset["annotations"]:
    if annotation["category_id"] not in category_count:
        category_count[annotation["category_id"]] = 0
    category_count[annotation["category_id"]] += 1

for category in dataset["categories"]:
    print("-%s: %d" % (category["name"], category_count[category["id"]]))


dataset = test_data
category_count = dict()
for annotation in dataset["annotations"]:
    if annotation["category_id"] not in category_count:
        category_count[annotation["category_id"]] = 0
    category_count[annotation["category_id"]] += 1

for category in dataset["categories"]:
    print("-%s: %d" % (category["name"], category_count[category["id"]]))
# Out:
# -neoplastic: 125
# -aphthous: 143
# -traumatic: 144
# -neoplastic: 26
# -aphthous: 31
# -traumatic: 30
